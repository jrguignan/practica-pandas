# %% [markdown]
# # Practica Libraria Pandas - Python #

# %% [markdown]
# ### Importar Pandas y Matplotlib ###

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Crear un dataframe a partir de un diccionario ###

# %%
#dicconario con datos
dic_data = {"Nombre":["Jose","Alvaro","Manuel","Ramon","Rafael"],"Edad":[18,19,20,18,17],"Calificacion":[15,16,18,19,11]}

#Contruir un datadrame a partir de un diccionario
df=pd.DataFrame(dic_data)

df

# %% [markdown]
# ### Crear un dataframe a partir de listas ###

# %%
#Seran las columnas del dataframe
col=["Nombre", "Edad", "Calificacion"]

#seran las filas del dataframe, sin la primera, que sera como la etiqueta
alumno1=["Jose",18,15]
alumno2=["alvaro",19,16]
alumno3=["Manuel",20,18]
alumno4=["Ramon",18,19]
alumno5=["Rafael",17,11]

df=pd.DataFrame([alumno1,alumno2,alumno3,alumno4,alumno5],columns=col)

df

# %% [markdown]
# ### Dataframe usando zip ###

# %%
col=["Nombre", "Edad", "Calificacion"]

Nombre=["Jose","Alvaro","Manuel","Ramon","Rafael"]
Edad=[18,19,20,18,17]
Calificacion=[15,16,18,19,11]

#la funcion zip crea tuplas con los valores dentro de nombre,edad,calificacion y luego con list pasan a ser listas
df=pd.DataFrame(list(zip(Nombre,Edad,Calificacion)), columns=col)

df

# %% [markdown]
# ### Agregar columnas a un dataframe ###

# %%
df["Pais"]=["Colombia","Venezuela","Ecuador","Colombia","Colombia"]

df

# %%
df=df.assign(Sueldo=[20000,25000,36000,45000,12000])

df

# %%
df.insert(2,'Colegio',["Marista","La Salle","La Salle","Maristas","Maristas"], True)

df

# %% [markdown]
# ### Seleccionar filas a un dataframe ###

# %%
condicion = df["Nombre"]=="Jose"
print(condicion)
df[condicion]

# %%
condicion = df.Edad.isin([16,17,19])
print(condicion)
df[condicion]

# %%
df.iloc[[0,2],:]

# %%
#Se selecciona por indice
df.loc[[0,3],["Nombre","Edad","Colegio"]]

# %% [markdown]
# ### Importar  archivo CSV ###

# %%
df_avocado = pd.read_csv("avocado.csv")

#muesta los primeras 8 filas
df_avocado.head(6)

# %%
#index elimina las primeras 2 filas
df_avocado = pd.read_csv("avocado.csv", index_col=1)

#muesta los primeras 4 ultimas filas
df_avocado.tail(4)

# %%
#index usa como indice las fechas
df_avocado = pd.read_csv("avocado.csv", index_col=["Date"])

#muesta los primeras 4 ultimas filas
df_avocado.head()

# %% [markdown]
# ### Graficas Matplotlib ###

# %%
#Agarrar los datos de Chicago y ordenar las fechas
df_avocado = pd.read_csv("avocado.csv")

#cambia el formato de fechas --> año - mes - dia
#se cambio el formato, para poder ordenar por fechas
df_fechas = pd.to_datetime(df_avocado['Date']).dt.strftime('%Y-%m-%d')
df_avocado["Fecha"] = df_fechas

#Elimina la columna Date
df_avocado = df_avocado.drop(['Date'], axis=1)

#guarda en df_chicago las columnas que tengan por region chicago
df_chicago = df_avocado[df_avocado["region"]=="Chicago"]

#Primero se coloca a fecha como indice y luego se ordena
df_chicago = df_chicago.set_index("Fecha")
df_chicago = df_chicago.sort_values(by="Fecha")

df_chicago.head()

# %%
MAX_SAMPLES=75

precio = df_chicago["AveragePrice"][: MAX_SAMPLES]
plt.plot(precio, label="Precio Medio")
#voltea las etiquetas del eje x 90 grados
plt.xticks(rotation=90)
plt.title("Precio del Aguacate Vs. Tiempo")
plt.xlabel("Fecha")
plt.ylabel("Precio")
plt.show()

# %%
MAX_SAMPLES=75
df_atlanta = df_avocado[df_avocado["region"]=="Atlanta"]

precio = df_atlanta["AveragePrice"]
Volumen = df_atlanta["Total Volume"]

bolsadeaguacate = df_atlanta["Total Bags"]
sbolsas = df_atlanta["Small Bags"]
lbolsas = df_atlanta["Large Bags"]
xbolsas = df_atlanta["XLarge Bags"]

plt.subplot(2,2,1)
plt.plot(precio, label="Precio", color="green")
plt.title("Precio del Aguacate Vs. Tiempo")
plt.legend()

plt.subplot(2,2,2)
plt.plot(Volumen, label="Volumen", color="red")
plt.title("Volumen de Aguacates")
plt.legend()

plt.subplot(2,2,3)
plt.plot(bolsadeaguacate, label="Bolsas Totales", color="blue")
plt.title("Bolsas Torales de Aguacates")
plt.legend()

plt.subplot(2,2,4)
plt.plot(sbolsas, label="Bolsas s", color="black")
plt.plot(lbolsas, label="Bolsas l", color="cyan")
plt.plot(xbolsas, label="Bolsas xl", color="yellow")
plt.title("Bolsas Por Tamaño")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analisis de encuesta de lenguajes de programacion ###

# %%
df_survey = pd.read_csv("survey_results_public.csv", index_col="ResponseId")
df_surveys = pd.read_csv("survey_results_schema.csv")

# %%
languages = "LanguageHaveWorkedWith"
salary = "ConvertedCompYearly"

# %%
#cambia los nombre de la columna LanguageHaveWorkedWith y ConvertedCompYearly
df_survey.rename(columns={languages: "Languages", salary: "Salary"}, inplace=True)

# %%
#Elimina los Nan de Languages y de Salary
df_survey.dropna(subset=['Languages', 'Salary'], inplace=True)

# %%
#Toma solo las columnas Country Salary y Languages, y las ordena por salario
df_survey = df_survey.loc[:,["Country","Salary","Languages"]].sort_values(by="Salary")
df_survey.head()
# Out:
#              Country  Salary  \
# ResponseId
# 65743          India     1.0
# 52006       Viet Nam     1.0
# 19913        Belgium     1.0
# 39916          India     1.0
# 36436          Japan     3.0
#
#                                                     Languages
# ResponseId
# 65743                                       C;C++;Java;Python
# 52006                                       C#;JavaScript;PHP
# 19913                   Java;PowerShell;Python;SQL;TypeScript
# 39916       Assembly;C#;HTML/CSS;JavaScript;MATLAB;PowerSh...
# 36436           C#;HTML/CSS;Java;JavaScript;Python;TypeScript

# %%
#condicional para filtrar los valores de salarios
filtro = (df_survey["Salary"] >= 10000) & (df_survey["Salary"]< 1e6)
df_survey = df_survey[filtro]

df_survey.head()
# Out:
#                              Country   Salary  \
# ResponseId
# 42161                         Turkey  10000.0
# 64088       United States of America  10000.0
# 3223        United States of America  10000.0
# 51614       United States of America  10000.0
# 37271       United States of America  10000.0
#
#                                                     Languages
# ResponseId
# 42161                                                  Delphi
# 64088       Bash/Shell;C;C#;HTML/CSS;JavaScript;PHP;Python...
# 3223        Bash/Shell;C;C#;HTML/CSS;Java;JavaScript;Lua;P...
# 51614           Bash/Shell;HTML/CSS;JavaScript;PHP;Python;SQL
# 37271       Bash/Shell;C++;HTML/CSS;JavaScript;PHP;TypeScript

# %%
#Crea una lista con todos los lenguajes de programacion en la encuesta
lengua = df_survey["Languages"]

all_languages=["Python"]
for  i in lengua:
    for l in i.split(";"):
        print(l)
        if l in all_languages:
            continue
        else:
            all_languages.append(l)
# Out:
# Delphi
# Bash/Shell
# C
# C#
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# HTML/CSS
# Java
# JavaScript
# Lua
# Python
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# Bash/Shell
# C++
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Bash/Shell
# Fortran
# MATLAB
# Python
# R
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# SQL
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# Ruby
# JavaScript
# Python
# SQL
# C
# C++
# HTML/CSS
# JavaScript
# Perl
# PHP
# Python
# Ruby
# SQL
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Elixir
# Erlang
# Groovy
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Objective-C
# PHP
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# PHP
# HTML/CSS
# JavaScript
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Dart
# Java
# Kotlin
# C#
# HTML/CSS
# JavaScript
# R
# SQL
# PowerShell
# Python
# SQL
# C
# Dart
# HTML/CSS
# Java
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# Python
# Solidity
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# Python
# HTML/CSS
# JavaScript
# PHP
# C
# C++
# HTML/CSS
# JavaScript
# PHP
# Assembly
# C
# C#
# C++
# Fortran
# Python
# SQL
# VBA
# Bash/Shell
# C++
# Go
# HTML/CSS
# Lua
# PowerShell
# Python
# Rust
# HTML/CSS
# JavaScript
# Python
# C
# C++
# Dart
# Java
# JavaScript
# Python
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# JavaScript
# TypeScript
# C#
# HTML/CSS
# SQL
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# JavaScript
# PHP
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# Python
# Bash/Shell
# Dart
# Java
# JavaScript
# Kotlin
# PowerShell
# Python
# Rust
# SQL
# TypeScript
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# MATLAB
# Python
# VBA
# C
# C#
# C++
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# F#
# Go
# HTML/CSS
# JavaScript
# PowerShell
# R
# SQL
# Bash/Shell
# JavaScript
# PHP
# SQL
# Bash/Shell
# Haskell
# HTML/CSS
# JavaScript
# Lua
# Python
# Rust
# Scala
# TypeScript
# Delphi
# C#
# JavaScript
# Python
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# MATLAB
# PowerShell
# Python
# SQL
# Dart
# Java
# Kotlin
# C++
# Java
# SQL
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# Bash/Shell
# C++
# C#
# HTML/CSS
# JavaScript
# Java
# SQL
# Bash/Shell
# Go
# PowerShell
# Python
# Bash/Shell
# C++
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Ruby
# Python
# SQL
# C#
# Bash/Shell
# C++
# HTML/CSS
# JavaScript
# Python
# SQL
# Python
# Dart
# Go
# HTML/CSS
# JavaScript
# MATLAB
# PHP
# Python
# SQL
# C#
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# JavaScript
# TypeScript
# C
# C#
# Java
# Kotlin
# SQL
# TypeScript
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# C#
# SQL
# C++
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# C
# C++
# Haskell
# HTML/CSS
# Java
# JavaScript
# Perl
# PHP
# Python
# SQL
# C
# C#
# HTML/CSS
# JavaScript
# PHP
# Python
# VBA
# Bash/Shell
# Elixir
# HTML/CSS
# JavaScript
# Python
# SQL
# C
# C#
# Go
# PHP
# Rust
# SQL
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# C#
# Java
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# C
# C#
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# Java
# JavaScript
# Python
# SQL
# TypeScript
# C#
# F#
# Go
# HTML/CSS
# JavaScript
# Kotlin
# MATLAB
# Python
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# Python
# Bash/Shell
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# PowerShell
# Python
# R
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# Dart
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Ruby
# TypeScript
# C
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# TypeScript
# VBA
# C#
# PowerShell
# C
# Java
# Kotlin
# Java
# JavaScript
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C#
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# Swift
# TypeScript
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Objective-C
# PHP
# PowerShell
# Python
# Rust
# Swift
# TypeScript
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# HTML/CSS
# Python
# R
# SQL
# C#
# C++
# Dart
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Python
# R
# SQL
# C
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Python
# Bash/Shell
# C
# C++
# Dart
# HTML/CSS
# JavaScript
# Kotlin
# Python
# SQL
# TypeScript
# Dart
# Objective-C
# Swift
# Fortran
# Python
# C++
# PHP
# PowerShell
# Python
# SQL
# C
# Java
# Kotlin
# SQL
# C
# Go
# HTML/CSS
# Java
# JavaScript
# Kotlin
# MATLAB
# Python
# HTML/CSS
# JavaScript
# Python
# C
# C++
# Haskell
# Java
# JavaScript
# Python
# SQL
# JavaScript
# PHP
# SQL
# Python
# C++
# Java
# Kotlin
# Python
# Bash/Shell
# C
# C#
# Java
# Kotlin
# HTML/CSS
# Java
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# TypeScript
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# Dart
# HTML/CSS
# Java
# JavaScript
# Solidity
# TypeScript
# Python
# SQL
# Assembly
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# R
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# C++
# HTML/CSS
# JavaScript
# TypeScript
# APL
# Bash/Shell
# C
# C#
# C++
# Go
# HTML/CSS
# Java
# JavaScript
# LISP
# Lua
# MATLAB
# PHP
# PowerShell
# Python
# R
# SQL
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# TypeScript
# C#
# C#
# Crystal
# HTML/CSS
# JavaScript
# SQL
# Python
# JavaScript
# Kotlin
# Python
# SQL
# Assembly
# Bash/Shell
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# VBA
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# PowerShell
# Python
# Go
# Groovy
# Haskell
# HTML/CSS
# Java
# JavaScript
# Julia
# Kotlin
# LISP
# Lua
# MATLAB
# OCaml
# Objective-C
# Perl
# C#
# Python
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# PHP
# Python
# TypeScript
# Delphi
# HTML/CSS
# JavaScript
# C#
# Java
# Bash/Shell
# C#
# Groovy
# HTML/CSS
# PowerShell
# Python
# SQL
# TypeScript
# Java
# Kotlin
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Java
# Ruby
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# Rust
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# Ruby
# Assembly
# Bash/Shell
# C
# C#
# C++
# Delphi
# Go
# HTML/CSS
# Java
# JavaScript
# Lua
# Perl
# PHP
# Python
# Ruby
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# Python
# SQL
# JavaScript
# TypeScript
# HTML/CSS
# Python
# SQL
# C#
# C++
# Go
# HTML/CSS
# JavaScript
# PHP
# Python
# Ruby
# SQL
# TypeScript
# C#
# C++
# PowerShell
# SQL
# Bash/Shell
# C
# C++
# Python
# C#
# C++
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# JavaScript
# TypeScript
# C#
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# SQL
# Swift
# Bash/Shell
# HTML/CSS
# Java
# PowerShell
# Python
# SQL
# TypeScript
# C#
# SQL
# Java
# JavaScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# Python
# TypeScript
# C++
# JavaScript
# Python
# Rust
# JavaScript
# Python
# SQL
# TypeScript
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# C#
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# C#
# SQL
# C
# C++
# MATLAB
# PHP
# Python
# SQL
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Kotlin
# MATLAB
# Python
# Dart
# Kotlin
# Python
# Delphi
# SQL
# C#
# JavaScript
# Kotlin
# Python
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# Dart
# Go
# Java
# JavaScript
# Lua
# SQL
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# Assembly
# Bash/Shell
# C
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# JavaScript
# Python
# HTML/CSS
# Java
# JavaScript
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# Ruby
# SQL
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# VBA
# C#
# JavaScript
# SQL
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Rust
# SQL
# TypeScript
# C#
# Java
# JavaScript
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# Java
# JavaScript
# Python
# SQL
# Dart
# Go
# Java
# JavaScript
# Python
# TypeScript
# Go
# HTML/CSS
# Java
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# Ruby
# R
# Bash/Shell
# Go
# HTML/CSS
# Python
# Rust
# TypeScript
# Elixir
# JavaScript
# PHP
# Python
# Rust
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Dart
# Assembly
# Bash/Shell
# C
# HTML/CSS
# Java
# JavaScript
# Objective-C
# PHP
# Python
# Ruby
# SQL
# Bash/Shell
# C
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# Bash/Shell
# C#
# C++
# JavaScript
# PowerShell
# Python
# C#
# Dart
# Java
# JavaScript
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# Assembly
# C
# Dart
# HTML/CSS
# Java
# JavaScript
# MATLAB
# PHP
# SQL
# R
# Delphi
# Bash/Shell
# HTML/CSS
# Python
# HTML/CSS
# JavaScript
# PHP
# Ruby
# PHP
# HTML/CSS
# Java
# JavaScript
# C#
# JavaScript
# SQL
# TypeScript
# Assembly
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# TypeScript
# JavaScript
# PHP
# SQL
# Bash/Shell
# C
# Bash/Shell
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C#
# C++
# Java
# JavaScript
# TypeScript
# Dart
# Go
# HTML/CSS
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# TypeScript
# Assembly
# Bash/Shell
# C
# C#
# C++
# Groovy
# Java
# Lua
# Python
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Bash/Shell
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Swift
# Dart
# Swift
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# JavaScript
# TypeScript
# C
# Java
# Objective-C
# SQL
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# C++
# Python
# HTML/CSS
# JavaScript
# PHP
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# Solidity
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Perl
# PHP
# PowerShell
# R
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# C#
# Dart
# HTML/CSS
# JavaScript
# MATLAB
# Python
# R
# SQL
# TypeScript
# VBA
# C#
# HTML/CSS
# JavaScript
# PHP
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# JavaScript
# PHP
# SQL
# JavaScript
# PHP
# Python
# TypeScript
# C
# C#
# Go
# HTML/CSS
# JavaScript
# Lua
# PHP
# SQL
# TypeScript
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# Objective-C
# SQL
# Swift
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# JavaScript
# JavaScript
# TypeScript
# Bash/Shell
# Python
# C#
# VBA
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PowerShell
# Python
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Bash/Shell
# JavaScript
# Python
# Rust
# HTML/CSS
# JavaScript
# C#
# Python
# SQL
# Bash/Shell
# C++
# Dart
# Elixir
# Go
# Haskell
# HTML/CSS
# Java
# JavaScript
# Lua
# PHP
# Python
# Rust
# SQL
# TypeScript
# C#
# Dart
# HTML/CSS
# JavaScript
# Assembly
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PowerShell
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# C#
# VBA
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Objective-C
# Python
# Rust
# JavaScript
# PHP
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Python
# SQL
# VBA
# Assembly
# Bash/Shell
# C
# C#
# C++
# COBOL
# Dart
# Delphi
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# TypeScript
# C#
# C++
# SQL
# HTML/CSS
# JavaScript
# Ruby
# Elixir
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Bash/Shell
# Java
# JavaScript
# SQL
# C++
# HTML/CSS
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# Python
# TypeScript
# Bash/Shell
# C
# C++
# Groovy
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# JavaScript
# TypeScript
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# Groovy
# Java
# JavaScript
# Kotlin
# SQL
# VBA
# Bash/Shell
# C
# C#
# C++
# Dart
# Delphi
# Java
# JavaScript
# Lua
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# VBA
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# Python
# TypeScript
# Kotlin
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# C
# Dart
# Go
# Kotlin
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# C
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# JavaScript
# TypeScript
# JavaScript
# HTML/CSS
# Java
# JavaScript
# PowerShell
# Python
# Scala
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# SQL
# Julia
# Python
# R
# Scala
# SQL
# VBA
# C#
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# C#
# Dart
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# C
# C++
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# Java
# Python
# Rust
# HTML/CSS
# Java
# JavaScript
# Kotlin
# SQL
# TypeScript
# Java
# JavaScript
# Kotlin
# SQL
# TypeScript
# Delphi
# C#
# JavaScript
# Python
# C#
# C++
# HTML/CSS
# JavaScript
# SQL
# Bash/Shell
# C#
# Dart
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# Java
# JavaScript
# Ruby
# HTML/CSS
# JavaScript
# PHP
# SQL
# COBOL
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Python
# SQL
# C
# Delphi
# HTML/CSS
# PHP
# C#
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# Swift
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# Python
# R
# Java
# Kotlin
# HTML/CSS
# JavaScript
# PHP
# Ruby
# SQL
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# Python
# TypeScript
# JavaScript
# Bash/Shell
# Go
# Java
# JavaScript
# PHP
# Python
# SQL
# C++
# Bash/Shell
# Python
# SQL
# Bash/Shell
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C
# HTML/CSS
# JavaScript
# Python
# SAS
# TypeScript
# MATLAB
# R
# HTML/CSS
# JavaScript
# Ruby
# HTML/CSS
# Java
# SQL
# JavaScript
# JavaScript
# Python
# TypeScript
# C#
# Dart
# HTML/CSS
# JavaScript
# Python
# SQL
# Java
# JavaScript
# MATLAB
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# TypeScript
# Go
# Python
# C#
# Go
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# Rust
# Scala
# TypeScript
# Dart
# HTML/CSS
# Java
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# MATLAB
# PHP
# Python
# C#
# Crystal
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# Bash/Shell
# Go
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C
# Java
# JavaScript
# Python
# Rust
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# Swift
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PowerShell
# HTML/CSS
# JavaScript
# Python
# VBA
# C#
# Java
# JavaScript
# PowerShell
# Python
# SQL
# C#
# C++
# Dart
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# PHP
# SAS
# SQL
# C#
# JavaScript
# SQL
# TypeScript
# C#
# Delphi
# HTML/CSS
# Java
# JavaScript
# MATLAB
# SAS
# SQL
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# C++
# C#
# HTML/CSS
# Java
# JavaScript
# PowerShell
# Python
# Ruby
# SQL
# Assembly
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# MATLAB
# PHP
# Python
# SQL
# C#
# Dart
# HTML/CSS
# JavaScript
# SQL
# Java
# Python
# SQL
# Swift
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# JavaScript
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# SQL
# C
# JavaScript
# PHP
# Python
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# C#
# Python
# C
# C#
# C++
# HTML/CSS
# Lua
# PowerShell
# Python
# SQL
# C++
# Delphi
# HTML/CSS
# Java
# JavaScript
# Lua
# Objective-C
# PHP
# SQL
# C#
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Python
# SQL
# JavaScript
# JavaScript
# TypeScript
# C#
# Python
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Python
# Delphi
# SQL
# HTML/CSS
# JavaScript
# HTML/CSS
# Java
# JavaScript
# Ruby
# TypeScript
# C#
# Dart
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Python
# Swift
# C
# C#
# C++
# Lua
# JavaScript
# PHP
# Python
# JavaScript
# PHP
# TypeScript
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# Go
# Kotlin
# PHP
# Python
# HTML/CSS
# JavaScript
# PHP
# SQL
# Python
# SQL
# JavaScript
# PHP
# Clojure
# Haskell
# JavaScript
# Bash/Shell
# Dart
# Groovy
# HTML/CSS
# JavaScript
# Kotlin
# Lua
# PHP
# SQL
# TypeScript
# C#
# JavaScript
# SQL
# HTML/CSS
# Java
# Python
# Bash/Shell
# C#
# C++
# Dart
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Perl
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# C++
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# C#
# Dart
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Dart
# Elixir
# HTML/CSS
# JavaScript
# Python
# Rust
# SQL
# TypeScript
# JavaScript
# C++
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# C
# HTML/CSS
# Java
# MATLAB
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# Lua
# Python
# SQL
# C#
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Python
# SQL
# TypeScript
# Bash/Shell
# Java
# JavaScript
# PHP
# Python
# Ruby
# Rust
# SQL
# TypeScript
# C
# Go
# HTML/CSS
# Java
# JavaScript
# Lua
# PHP
# Python
# SQL
# JavaScript
# HTML/CSS
# JavaScript
# SQL
# Go
# Java
# JavaScript
# PHP
# TypeScript
# C++
# HTML/CSS
# JavaScript
# MATLAB
# Python
# SQL
# TypeScript
# HTML/CSS
# PowerShell
# Python
# Scala
# SQL
# TypeScript
# VBA
# Assembly
# C#
# C++
# COBOL
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Python
# SQL
# VBA
# C#
# HTML/CSS
# JavaScript
# SQL
# Dart
# HTML/CSS
# Java
# Kotlin
# PHP
# SQL
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C#
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# Python
# SQL
# C
# C#
# C++
# Java
# JavaScript
# Lua
# PHP
# PowerShell
# Python
# Scala
# SQL
# VBA
# C#
# JavaScript
# PowerShell
# Python
# SQL
# TypeScript
# VBA
# HTML/CSS
# JavaScript
# Ruby
# SQL
# C
# Dart
# Java
# Kotlin
# PHP
# SQL
# HTML/CSS
# JavaScript
# PHP
# Dart
# HTML/CSS
# JavaScript
# Kotlin
# Python
# Ruby
# Rust
# TypeScript
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C
# C++
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Python
# SQL
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# JavaScript
# TypeScript
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# HTML/CSS
# JavaScript
# C
# C#
# HTML/CSS
# Java
# JavaScript
# R
# SQL
# TypeScript
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# Bash/Shell
# C#
# Go
# PowerShell
# Python
# SQL
# VBA
# Java
# C#
# HTML/CSS
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# MATLAB
# PHP
# Python
# SQL
# TypeScript
# JavaScript
# TypeScript
# C
# C#
# C++
# HTML/CSS
# JavaScript
# Python
# Solidity
# C
# C++
# PowerShell
# Python
# SQL
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# JavaScript
# TypeScript
# C#
# HTML/CSS
# Java
# JavaScript
# Python
# R
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Python
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# C
# C#
# Dart
# Go
# HTML/CSS
# Java
# JavaScript
# Kotlin
# MATLAB
# PHP
# Python
# SQL
# TypeScript
# Bash/Shell
# C
# HTML/CSS
# JavaScript
# PHP
# C++
# HTML/CSS
# JavaScript
# Python
# HTML/CSS
# JavaScript
# Ruby
# TypeScript
# Assembly
# Bash/Shell
# C
# C#
# C++
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Lua
# MATLAB
# PHP
# PowerShell
# Python
# R
# SQL
# Swift
# TypeScript
# VBA
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# Dart
# Objective-C
# Swift
# HTML/CSS
# JavaScript
# Solidity
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# VBA
# Haskell
# HTML/CSS
# JavaScript
# Dart
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# Java
# JavaScript
# Kotlin
# TypeScript
# Assembly
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# Dart
# Go
# Python
# Swift
# HTML/CSS
# Java
# JavaScript
# Objective-C
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Java
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Lua
# PHP
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# PHP
# TypeScript
# C++
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C#
# SQL
# Go
# Java
# Kotlin
# Python
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# Java
# JavaScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SAS
# SQL
# TypeScript
# Bash/Shell
# C
# C++
# Go
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Python
# Rust
# SQL
# TypeScript
# C
# C++
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Python
# SQL
# C#
# C++
# HTML/CSS
# JavaScript
# SQL
# Java
# JavaScript
# TypeScript
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# Java
# Python
# SQL
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# C#
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# PHP
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# Java
# JavaScript
# SQL
# Assembly
# Bash/Shell
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# Rust
# SQL
# JavaScript
# PHP
# TypeScript
# Dart
# C
# HTML/CSS
# JavaScript
# PHP
# Python
# JavaScript
# Go
# HTML/CSS
# Java
# JavaScript
# Python
# HTML/CSS
# Python
# R
# Java
# Kotlin
# SQL
# Assembly
# Bash/Shell
# C++
# HTML/CSS
# JavaScript
# MATLAB
# Ruby
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# C++
# HTML/CSS
# JavaScript
# PHP
# SQL
# Delphi
# Python
# C
# Java
# MATLAB
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C#
# Python
# Delphi
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# TypeScript
# JavaScript
# PHP
# Python
# SQL
# JavaScript
# Python
# SQL
# Java
# Python
# SQL
# C#
# JavaScript
# Python
# Swift
# TypeScript
# Dart
# JavaScript
# MATLAB
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# SAS
# TypeScript
# Dart
# Go
# JavaScript
# TypeScript
# HTML/CSS
# Java
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# PowerShell
# TypeScript
# HTML/CSS
# JavaScript
# Kotlin
# Swift
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# VBA
# HTML/CSS
# JavaScript
# TypeScript
# C#
# Java
# SQL
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# VBA
# C++
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Python
# SQL
# Swift
# TypeScript
# Bash/Shell
# Objective-C
# Python
# Swift
# JavaScript
# Python
# SQL
# C#
# C++
# Dart
# Delphi
# JavaScript
# PHP
# SQL
# C#
# C#
# HTML/CSS
# JavaScript
# Python
# C
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Python
# SQL
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Ruby
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Perl
# SQL
# TypeScript
# JavaScript
# PHP
# SQL
# TypeScript
# C#
# C++
# Elixir
# F#
# Go
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C
# C#
# C++
# Java
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# JavaScript
# PHP
# SQL
# Assembly
# C#
# C++
# Delphi
# HTML/CSS
# Java
# JavaScript
# MATLAB
# PHP
# SQL
# TypeScript
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Assembly
# C#
# C++
# Java
# JavaScript
# Python
# Scala
# SQL
# TypeScript
# Python
# C
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# Swift
# APL
# Assembly
# Bash/Shell
# C
# C#
# Crystal
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# LISP
# MATLAB
# Objective-C
# PHP
# PowerShell
# Python
# SAS
# SQL
# Swift
# TypeScript
# VBA
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# Python
# VBA
# Assembly
# Bash/Shell
# C
# C#
# C++
# Haskell
# HTML/CSS
# Java
# JavaScript
# Lua
# Python
# C#
# JavaScript
# C
# C++
# Python
# Rust
# Assembly
# C#
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# PowerShell
# SQL
# Swift
# TypeScript
# VBA
# C#
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# C
# C++
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Python
# SQL
# Delphi
# HTML/CSS
# JavaScript
# PHP
# SQL
# Dart
# Java
# Kotlin
# Objective-C
# Python
# Swift
# Bash/Shell
# C
# C++
# Dart
# HTML/CSS
# Java
# JavaScript
# MATLAB
# PHP
# PowerShell
# Python
# R
# SQL
# TypeScript
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# C
# C#
# C++
# Fortran
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# Scala
# SQL
# C#
# Delphi
# Java
# JavaScript
# SQL
# VBA
# HTML/CSS
# JavaScript
# PHP
# SQL
# JavaScript
# PHP
# TypeScript
# Python
# C#
# Go
# Python
# Rust
# TypeScript
# C#
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Assembly
# JavaScript
# Python
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# TypeScript
# Java
# JavaScript
# Python
# TypeScript
# Bash/Shell
# HTML/CSS
# MATLAB
# Python
# R
# SAS
# SQL
# Bash/Shell
# HTML/CSS
# Python
# R
# Dart
# Java
# Kotlin
# HTML/CSS
# JavaScript
# Python
# R
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# PowerShell
# Python
# SQL
# Dart
# HTML/CSS
# JavaScript
# Lua
# Perl
# Python
# SQL
# Assembly
# C#
# C++
# Delphi
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# Assembly
# C#
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Python
# SQL
# JavaScript
# Python
# APL
# Java
# Python
# HTML/CSS
# JavaScript
# Python
# HTML/CSS
# JavaScript
# TypeScript
# C++
# C
# Java
# HTML/CSS
# JavaScript
# C#
# HTML/CSS
# SQL
# C#
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# TypeScript
# C#
# Dart
# SQL
# TypeScript
# C#
# Java
# SQL
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# VBA
# C#
# Kotlin
# SQL
# Swift
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# SQL
# TypeScript
# JavaScript
# Python
# SQL
# Groovy
# Java
# PowerShell
# Python
# SQL
# TypeScript
# VBA
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Python
# SQL
# C
# C#
# C++
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# C#
# JavaScript
# HTML/CSS
# JavaScript
# Julia
# MATLAB
# Python
# R
# Bash/Shell
# JavaScript
# Python
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Bash/Shell
# C
# C#
# C++
# Dart
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# PowerShell
# SQL
# TypeScript
# Dart
# Java
# Kotlin
# Perl
# Python
# Ruby
# JavaScript
# TypeScript
# Delphi
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# C#
# Dart
# HTML/CSS
# JavaScript
# PHP
# Python
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# C#
# HTML/CSS
# JavaScript
# SQL
# Swift
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# C
# C#
# C++
# Java
# Kotlin
# PHP
# SQL
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C
# C++
# JavaScript
# Objective-C
# SQL
# Swift
# C#
# HTML/CSS
# JavaScript
# SQL
# C#
# HTML/CSS
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# Java
# Python
# SQL
# HTML/CSS
# Java
# JavaScript
# Python
# R
# TypeScript
# Objective-C
# Swift
# Dart
# HTML/CSS
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# MATLAB
# Python
# SQL
# TypeScript
# VBA
# C++
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Python
# R
# SQL
# C#
# JavaScript
# TypeScript
# PHP
# C#
# HTML/CSS
# JavaScript
# SQL
# VBA
# JavaScript
# PHP
# Ruby
# SQL
# Python
# Java
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Bash/Shell
# Delphi
# JavaScript
# PowerShell
# Python
# SQL
# C
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# C#
# Delphi
# Perl
# SQL
# VBA
# JavaScript
# TypeScript
# C++
# Delphi
# Java
# JavaScript
# Python
# Delphi
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# PowerShell
# Python
# Ruby
# Rust
# SQL
# TypeScript
# JavaScript
# TypeScript
# C#
# JavaScript
# HTML/CSS
# JavaScript
# TypeScript
# Python
# R
# C#
# JavaScript
# PowerShell
# SQL
# TypeScript
# Bash/Shell
# Perl
# Ruby
# C#
# Delphi
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# Python
# SQL
# C
# HTML/CSS
# Objective-C
# Swift
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C#
# JavaScript
# PHP
# TypeScript
# C
# C++
# JavaScript
# Objective-C
# Python
# Rust
# Swift
# C++
# Python
# Python
# SQL
# Delphi
# Delphi
# HTML/CSS
# JavaScript
# TypeScript
# Go
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# Java
# JavaScript
# MATLAB
# PHP
# PowerShell
# Bash/Shell
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# Delphi
# C#
# HTML/CSS
# HTML/CSS
# JavaScript
# PHP
# Python
# JavaScript
# Python
# R
# SQL
# Assembly
# C++
# Delphi
# Java
# Python
# SQL
# JavaScript
# Python
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# Java
# Delphi
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# C
# HTML/CSS
# JavaScript
# Lua
# Python
# SQL
# TypeScript
# Delphi
# Java
# Dart
# HTML/CSS
# JavaScript
# TypeScript
# Kotlin
# C#
# Dart
# HTML/CSS
# JavaScript
# Python
# SQL
# Java
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# C#
# JavaScript
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# VBA
# C#
# HTML/CSS
# JavaScript
# SQL
# Java
# Python
# SQL
# Swift
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# Java
# HTML/CSS
# JavaScript
# Python
# TypeScript
# C#
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# Swift
# C
# C++
# Java
# JavaScript
# MATLAB
# PHP
# Python
# SQL
# HTML/CSS
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# Swift
# TypeScript
# HTML/CSS
# JavaScript
# Python
# SQL
# Assembly
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Lua
# Perl
# PHP
# Python
# Ruby
# SQL
# Python
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# C#
# C++
# HTML/CSS
# JavaScript
# PowerShell
# Python
# Rust
# TypeScript
# TypeScript
# HTML/CSS
# JavaScript
# Python
# TypeScript
# HTML/CSS
# Java
# JavaScript
# HTML/CSS
# JavaScript
# TypeScript
# Java
# Kotlin
# JavaScript
# Go
# JavaScript
# PHP
# SQL
# TypeScript
# C#
# R
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# C#
# Fortran
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# C#
# Python
# SQL
# Java
# JavaScript
# Python
# Scala
# SQL
# TypeScript
# C#
# Java
# JavaScript
# PowerShell
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# C
# C++
# Python
# HTML/CSS
# JavaScript
# PHP
# JavaScript
# Python
# C#
# C
# C#
# Go
# HTML/CSS
# JavaScript
# Objective-C
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# C++
# Delphi
# F#
# HTML/CSS
# JavaScript
# PHP
# SQL
# VBA
# Dart
# Python
# Swift
# C#
# JavaScript
# SQL
# C#
# Delphi
# Java
# JavaScript
# PHP
# Python
# SQL
# C++
# Dart
# Java
# JavaScript
# PHP
# SQL
# Swift
# TypeScript
# C#
# C++
# Dart
# Kotlin
# Python
# SQL
# VBA
# Python
# Rust
# C
# C++
# PHP
# Bash/Shell
# C++
# HTML/CSS
# JavaScript
# PHP
# Python
# Scala
# SQL
# Swift
# TypeScript
# Assembly
# Bash/Shell
# C
# C#
# C++
# F#
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# PowerShell
# Python
# Rust
# SQL
# TypeScript
# Bash/Shell
# C#
# Dart
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# C#
# Java
# Bash/Shell
# C#
# C++
# Dart
# HTML/CSS
# Python
# SQL
# TypeScript
# Bash/Shell
# C
# C++
# HTML/CSS
# JavaScript
# Perl
# Python
# TypeScript
# C
# Python
# Swift
# C#
# HTML/CSS
# JavaScript
# SQL
# Bash/Shell
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Dart
# Go
# HTML/CSS
# Java
# JavaScript
# Python
# Ruby
# SQL
# TypeScript
# Python
# Rust
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# SQL
# Python
# SQL
# C
# C++
# C
# C#
# HTML/CSS
# Java
# SQL
# JavaScript
# Kotlin
# PHP
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# PHP
# SQL
# Go
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# C
# C#
# C++
# Go
# HTML/CSS
# JavaScript
# C#
# Go
# HTML/CSS
# JavaScript
# PHP
# Python
# Rust
# TypeScript
# HTML/CSS
# JavaScript
# Python
# SQL
# C#
# HTML/CSS
# Java
# C++
# Java
# Kotlin
# Python
# SQL
# Bash/Shell
# C
# Haskell
# HTML/CSS
# JavaScript
# PHP
# Python
# Rust
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# Dart
# Go
# Python
# Bash/Shell
# C
# Dart
# Groovy
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Python
# HTML/CSS
# JavaScript
# Python
# C++
# HTML/CSS
# JavaScript
# Python
# Bash/Shell
# Delphi
# HTML/CSS
# JavaScript
# Lua
# PHP
# SQL
# Assembly
# Bash/Shell
# C
# C#
# C++
# Dart
# Delphi
# Go
# HTML/CSS
# Java
# JavaScript
# Lua
# PHP
# Python
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# C++
# Swift
# Fortran
# MATLAB
# Python
# VBA
# Bash/Shell
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# TypeScript
# C#
# JavaScript
# Python
# C#
# Dart
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# TypeScript
# VBA
# HTML/CSS
# Java
# JavaScript
# PHP
# Ruby
# SQL
# C#
# PHP
# SQL
# C
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C++
# Dart
# HTML/CSS
# JavaScript
# Python
# Bash/Shell
# C
# C++
# Go
# HTML/CSS
# JavaScript
# Python
# Rust
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Python
# R
# SQL
# TypeScript
# PowerShell
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# SQL
# TypeScript
# C++
# Java
# JavaScript
# Python
# SQL
# C#
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# Java
# Java
# JavaScript
# Rust
# TypeScript
# C#
# JavaScript
# SQL
# HTML/CSS
# PHP
# SQL
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# Objective-C
# PHP
# PowerShell
# SQL
# Dart
# HTML/CSS
# JavaScript
# Objective-C
# Python
# Ruby
# SQL
# Swift
# C#
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C
# C#
# C++
# Go
# HTML/CSS
# Java
# JavaScript
# Python
# Bash/Shell
# C
# Dart
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# Swift
# C#
# C++
# Java
# Python
# Java
# Python
# Bash/Shell
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Bash/Shell
# C
# C++
# Java
# JavaScript
# Kotlin
# LISP
# MATLAB
# Python
# R
# Ruby
# SQL
# TypeScript
# C++
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Python
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# Bash/Shell
# JavaScript
# JavaScript
# TypeScript
# Bash/Shell
# C++
# Go
# JavaScript
# Lua
# Python
# Rust
# SQL
# TypeScript
# C
# C++
# Dart
# Java
# JavaScript
# Python
# HTML/CSS
# JavaScript
# Python
# Bash/Shell
# C#
# Haskell
# HTML/CSS
# Java
# JavaScript
# PowerShell
# Python
# Bash/Shell
# C
# Java
# JavaScript
# Kotlin
# SQL
# COBOL
# SQL
# C
# Swift
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# Python
# Scala
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# C#
# JavaScript
# SQL
# Bash/Shell
# C
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Python
# Bash/Shell
# C#
# Delphi
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# C#
# Dart
# HTML/CSS
# JavaScript
# Kotlin
# Python
# SQL
# Swift
# HTML/CSS
# JavaScript
# PHP
# Assembly
# C
# C#
# C++
# Dart
# Java
# JavaScript
# Kotlin
# Rust
# TypeScript
# JavaScript
# TypeScript
# C
# C++
# Python
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# C#
# HTML/CSS
# JavaScript
# TypeScript
# JavaScript
# Python
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# Java
# JavaScript
# MATLAB
# PHP
# Python
# R
# SQL
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Elixir
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# C
# Java
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# Haskell
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# C
# C++
# Fortran
# HTML/CSS
# Python
# Java
# Solidity
# C#
# HTML/CSS
# JavaScript
# SQL
# C++
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# Kotlin
# TypeScript
# Assembly
# C
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Delphi
# Go
# PHP
# SQL
# TypeScript
# C#
# SQL
# Go
# HTML/CSS
# PHP
# TypeScript
# Dart
# Go
# HTML/CSS
# Java
# JavaScript
# TypeScript
# JavaScript
# TypeScript
# Dart
# Java
# Kotlin
# Clojure
# JavaScript
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C#
# C++
# Python
# SQL
# JavaScript
# Objective-C
# Swift
# HTML/CSS
# JavaScript
# Ruby
# JavaScript
# Python
# SQL
# TypeScript
# JavaScript
# PHP
# TypeScript
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# Python
# C#
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Bash/Shell
# C#
# C++
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C++
# HTML/CSS
# JavaScript
# MATLAB
# Python
# Python
# C#
# JavaScript
# Scala
# TypeScript
# Java
# SQL
# Java
# PHP
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# JavaScript
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# Python
# R
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# Ruby
# Bash/Shell
# Go
# HTML/CSS
# JavaScript
# TypeScript
# C#
# C++
# HTML/CSS
# JavaScript
# Groovy
# Java
# JavaScript
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# Delphi
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# VBA
# Java
# JavaScript
# Python
# Solidity
# TypeScript
# Java
# Python
# SQL
# C#
# JavaScript
# SQL
# TypeScript
# C
# C++
# Python
# Rust
# C#
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Python
# R
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# C++
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# MATLAB
# Python
# R
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Rust
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# SQL
# TypeScript
# Bash/Shell
# Clojure
# Dart
# HTML/CSS
# Java
# JavaScript
# SQL
# JavaScript
# PHP
# Kotlin
# Bash/Shell
# C#
# C++
# Go
# PowerShell
# Python
# SQL
# VBA
# C#
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# Java
# PHP
# Python
# SQL
# Bash/Shell
# C++
# Lua
# Python
# Java
# Bash/Shell
# Go
# JavaScript
# PowerShell
# Python
# C
# C#
# Dart
# HTML/CSS
# Java
# JavaScript
# Python
# TypeScript
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# Python
# Ruby
# SQL
# HTML/CSS
# Java
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# PHP
# SQL
# C#
# Dart
# Go
# HTML/CSS
# JavaScript
# PHP
# Rust
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# VBA
# C#
# HTML/CSS
# Python
# C
# C#
# C++
# Dart
# Elixir
# Go
# Java
# JavaScript
# Kotlin
# Objective-C
# R
# Ruby
# Rust
# Swift
# TypeScript
# Assembly
# C
# C#
# C++
# HTML/CSS
# JavaScript
# MATLAB
# SQL
# VBA
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Lua
# PHP
# SQL
# JavaScript
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# MATLAB
# Python
# C#
# SQL
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C
# C#
# C++
# Dart
# Java
# Kotlin
# MATLAB
# Python
# SQL
# Java
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# Python
# Assembly
# C
# C#
# Delphi
# HTML/CSS
# Java
# JavaScript
# MATLAB
# PHP
# C#
# F#
# HTML/CSS
# JavaScript
# Rust
# SQL
# TypeScript
# C#
# SQL
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# C#
# HTML/CSS
# Java
# JavaScript
# TypeScript
# C
# HTML/CSS
# Python
# Scala
# SQL
# VBA
# C#
# Delphi
# Java
# SQL
# C#
# HTML/CSS
# JavaScript
# Kotlin
# Bash/Shell
# JavaScript
# Python
# SQL
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# HTML/CSS
# Java
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# PowerShell
# Python
# Dart
# SQL
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# R
# Solidity
# SQL
# TypeScript
# VBA
# Bash/Shell
# Go
# Java
# Kotlin
# Python
# SQL
# JavaScript
# SQL
# C
# C++
# Go
# Groovy
# HTML/CSS
# Python
# R
# SQL
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# Dart
# HTML/CSS
# Java
# JavaScript
# Python
# Rust
# Solidity
# SQL
# TypeScript
# C#
# JavaScript
# SQL
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Lua
# MATLAB
# Python
# C#
# Groovy
# HTML/CSS
# PowerShell
# SQL
# Dart
# HTML/CSS
# JavaScript
# HTML/CSS
# Java
# JavaScript
# HTML/CSS
# SQL
# VBA
# HTML/CSS
# JavaScript
# PHP
# Bash/Shell
# Go
# HTML/CSS
# JavaScript
# Python
# Rust
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Rust
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# JavaScript
# TypeScript
# C#
# C++
# HTML/CSS
# JavaScript
# SQL
# C#
# C++
# Java
# SQL
# Java
# Kotlin
# Swift
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Bash/Shell
# Java
# Python
# JavaScript
# Python
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# TypeScript
# C
# C#
# C++
# Java
# Kotlin
# MATLAB
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Swift
# C
# HTML/CSS
# JavaScript
# Kotlin
# PHP
# SQL
# TypeScript
# C
# C++
# Go
# Java
# Python
# C#
# JavaScript
# SQL
# TypeScript
# C#
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# C++
# Java
# MATLAB
# Python
# SQL
# C#
# Python
# SQL
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# C#
# SQL
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C#
# Dart
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C
# C++
# Groovy
# HTML/CSS
# JavaScript
# Java
# Kotlin
# Go
# HTML/CSS
# JavaScript
# PHP
# Python
# Ruby
# SQL
# TypeScript
# C#
# Dart
# HTML/CSS
# JavaScript
# Ruby
# SQL
# TypeScript
# Dart
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Rust
# SQL
# TypeScript
# Python
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C#
# JavaScript
# Python
# TypeScript
# C#
# Go
# HTML/CSS
# JavaScript
# Python
# HTML/CSS
# JavaScript
# Python
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# VBA
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Julia
# Python
# TypeScript
# Dart
# HTML/CSS
# JavaScript
# Python
# SQL
# C#
# HTML/CSS
# JavaScript
# Kotlin
# PHP
# PowerShell
# Python
# SQL
# Bash/Shell
# Python
# C#
# Python
# SQL
# Delphi
# SQL
# C
# Java
# Rust
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# PHP
# SQL
# Bash/Shell
# Perl
# Python
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# Java
# JavaScript
# SQL
# Bash/Shell
# C#
# Dart
# Go
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Ruby
# SQL
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# Dart
# Go
# LISP
# Python
# Rust
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# C#
# Dart
# JavaScript
# HTML/CSS
# JavaScript
# Python
# SQL
# C
# C#
# HTML/CSS
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# Python
# TypeScript
# C
# C#
# HTML/CSS
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# Kotlin
# Objective-C
# Swift
# C#
# JavaScript
# C#
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Objective-C
# SQL
# Swift
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Python
# Rust
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Java
# PowerShell
# TypeScript
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Bash/Shell
# HTML/CSS
# Java
# PowerShell
# SQL
# TypeScript
# Java
# SQL
# C++
# Java
# JavaScript
# PHP
# Python
# C#
# C++
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# Java
# JavaScript
# Python
# TypeScript
# JavaScript
# TypeScript
# Bash/Shell
# Python
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# VBA
# C
# Python
# C#
# Java
# PHP
# TypeScript
# HTML/CSS
# JavaScript
# Ruby
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# C#
# SQL
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# TypeScript
# Python
# SQL
# VBA
# Assembly
# C#
# Java
# Swift
# C++
# HTML/CSS
# Java
# SQL
# JavaScript
# C++
# HTML/CSS
# JavaScript
# Lua
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Go
# JavaScript
# Python
# Rust
# TypeScript
# Bash/Shell
# C
# C#
# C++
# C#
# C++
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Python
# SQL
# VBA
# HTML/CSS
# JavaScript
# Kotlin
# PHP
# SAS
# SQL
# TypeScript
# C#
# Delphi
# Python
# SQL
# C#
# Python
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# C#
# JavaScript
# SQL
# TypeScript
# JavaScript
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C
# C++
# Groovy
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# JavaScript
# TypeScript
# Python
# HTML/CSS
# JavaScript
# PHP
# SQL
# C
# HTML/CSS
# Java
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# Python
# TypeScript
# Dart
# Java
# JavaScript
# Kotlin
# Python
# SQL
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Clojure
# HTML/CSS
# JavaScript
# PHP
# Python
# TypeScript
# C++
# HTML/CSS
# JavaScript
# PHP
# Python
# APL
# Assembly
# Bash/Shell
# C
# C#
# C++
# Crystal
# Dart
# HTML/CSS
# Java
# JavaScript
# Lua
# Objective-C
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# JavaScript
# PHP
# Objective-C
# Swift
# HTML/CSS
# JavaScript
# TypeScript
# C
# C++
# HTML/CSS
# TypeScript
# Bash/Shell
# C
# Java
# Lua
# Python
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# JavaScript
# Python
# TypeScript
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# COBOL
# Python
# HTML/CSS
# JavaScript
# PHP
# Python
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Lua
# Objective-C
# PHP
# Python
# SQL
# VBA
# Bash/Shell
# Java
# PowerShell
# Python
# SQL
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# C
# C++
# Python
# Rust
# Bash/Shell
# C
# HTML/CSS
# Java
# PHP
# Python
# SQL
# C
# C#
# C++
# Go
# HTML/CSS
# JavaScript
# HTML/CSS
# Java
# JavaScript
# SQL
# C#
# JavaScript
# SQL
# C#
# HTML/CSS
# Java
# JavaScript
# PowerShell
# TypeScript
# Go
# HTML/CSS
# JavaScript
# Python
# TypeScript
# Bash/Shell
# C++
# Elixir
# Erlang
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# Assembly
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# LISP
# PowerShell
# SQL
# TypeScript
# C#
# Java
# PHP
# Python
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# SQL
# HTML/CSS
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# C++
# Clojure
# Dart
# Go
# Haskell
# JavaScript
# PHP
# Rust
# TypeScript
# Fortran
# Python
# R
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# HTML/CSS
# Java
# JavaScript
# PowerShell
# Python
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# VBA
# Bash/Shell
# Go
# C#
# SQL
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# JavaScript
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# Java
# Python
# JavaScript
# PHP
# Ruby
# SQL
# C#
# JavaScript
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Bash/Shell
# Java
# Python
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Bash/Shell
# C
# Go
# Java
# Lua
# Python
# SQL
# HTML/CSS
# JavaScript
# Python
# SQL
# C++
# HTML/CSS
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# Objective-C
# PHP
# Python
# Swift
# Bash/Shell
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# Kotlin
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# SQL
# Swift
# VBA
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# PHP
# Python
# SQL
# HTML/CSS
# PHP
# SQL
# VBA
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# SQL
# TypeScript
# C
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Java
# Kotlin
# C#
# HTML/CSS
# JavaScript
# PHP
# C
# C++
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Python
# SQL
# Java
# Python
# C#
# JavaScript
# SQL
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# JavaScript
# Python
# R
# Scala
# SQL
# TypeScript
# Elixir
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# SQL
# C
# C++
# JavaScript
# PHP
# Swift
# TypeScript
# Bash/Shell
# C#
# C++
# Dart
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# Ruby
# SQL
# VBA
# Bash/Shell
# C++
# HTML/CSS
# JavaScript
# PHP
# Python
# Ruby
# SQL
# TypeScript
# Bash/Shell
# Python
# R
# SQL
# Bash/Shell
# C
# C#
# C++
# Dart
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PHP
# R
# SQL
# TypeScript
# VBA
# Java
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# HTML/CSS
# JavaScript
# PowerShell
# Python
# TypeScript
# C#
# C++
# SQL
# Python
# Bash/Shell
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# VBA
# C#
# Java
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# C++
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# MATLAB
# VBA
# JavaScript
# Python
# TypeScript
# C#
# C++
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Objective-C
# PHP
# PowerShell
# Python
# SQL
# Swift
# Java
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Bash/Shell
# Go
# HTML/CSS
# Python
# Rust
# Bash/Shell
# Dart
# Go
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Objective-C
# PHP
# PowerShell
# Python
# Rust
# Solidity
# SQL
# Swift
# TypeScript
# C
# C#
# C++
# Go
# Java
# Kotlin
# Python
# Rust
# HTML/CSS
# JavaScript
# PHP
# SQL
# HTML/CSS
# Java
# JavaScript
# SQL
# C#
# C++
# Java
# PowerShell
# SQL
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Python
# SQL
# Java
# SQL
# Bash/Shell
# C#
# PowerShell
# Python
# Python
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# VBA
# Go
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Bash/Shell
# Dart
# Go
# HTML/CSS
# JavaScript
# PHP
# Rust
# TypeScript
# Elixir
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# HTML/CSS
# SQL
# HTML/CSS
# JavaScript
# Python
# R
# SQL
# Bash/Shell
# C++
# HTML/CSS
# Java
# JavaScript
# PowerShell
# SQL
# TypeScript
# VBA
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# C
# C#
# C++
# Clojure
# COBOL
# Groovy
# Julia
# Kotlin
# Scala
# VBA
# C#
# HTML/CSS
# JavaScript
# Python
# HTML/CSS
# Java
# JavaScript
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# Go
# JavaScript
# PHP
# Rust
# SQL
# Bash/Shell
# Elixir
# Python
# R
# Rust
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# C
# MATLAB
# PowerShell
# Python
# VBA
# Java
# SQL
# Bash/Shell
# Java
# SQL
# HTML/CSS
# JavaScript
# C#
# HTML/CSS
# JavaScript
# SQL
# C++
# Java
# JavaScript
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# Dart
# C#
# C++
# Java
# Kotlin
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# Go
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Ruby
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# Kotlin
# PHP
# Python
# SQL
# Swift
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# C
# Python
# SQL
# PHP
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# C#
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# TypeScript
# C#
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# Dart
# JavaScript
# Kotlin
# PowerShell
# Python
# SQL
# TypeScript
# JavaScript
# Python
# Bash/Shell
# C#
# C++
# SQL
# TypeScript
# Bash/Shell
# C
# SQL
# JavaScript
# TypeScript
# Kotlin
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# Bash/Shell
# C
# Java
# Kotlin
# PowerShell
# SQL
# VBA
# HTML/CSS
# JavaScript
# SAS
# SQL
# TypeScript
# Bash/Shell
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Java
# JavaScript
# SQL
# VBA
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Lua
# PHP
# PowerShell
# SQL
# TypeScript
# Dart
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# JavaScript
# C#
# C++
# Java
# JavaScript
# Kotlin
# MATLAB
# PowerShell
# Python
# SQL
# C
# C#
# C++
# Haskell
# HTML/CSS
# Java
# JavaScript
# Python
# TypeScript
# C++
# C#
# JavaScript
# Python
# SQL
# TypeScript
# Java
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# Delphi
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# Bash/Shell
# Java
# Python
# PHP
# Python
# SQL
# HTML/CSS
# JavaScript
# PHP
# Go
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C
# C#
# C++
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C
# Go
# Java
# JavaScript
# Lua
# PHP
# Python
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C
# C#
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# JavaScript
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# Kotlin
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C
# Dart
# Go
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Lua
# MATLAB
# PHP
# SQL
# Swift
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Rust
# SQL
# TypeScript
# Java
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# Ruby
# SQL
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# C
# C#
# C++
# Elixir
# Erlang
# HTML/CSS
# Java
# JavaScript
# Objective-C
# PowerShell
# Python
# Ruby
# SQL
# Elixir
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Delphi
# Java
# JavaScript
# Python
# SQL
# C
# C++
# Dart
# Java
# JavaScript
# SQL
# Delphi
# JavaScript
# TypeScript
# Dart
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Assembly
# Bash/Shell
# C
# C++
# HTML/CSS
# JavaScript
# Kotlin
# MATLAB
# Python
# Rust
# TypeScript
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# JavaScript
# PHP
# SQL
# JavaScript
# TypeScript
# Python
# SQL
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# C
# C++
# Dart
# Fortran
# HTML/CSS
# Java
# JavaScript
# Python
# R
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# Fortran
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# VBA
# Python
# Bash/Shell
# C
# C#
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# Python
# Scala
# Solidity
# SQL
# TypeScript
# Python
# SQL
# Bash/Shell
# Java
# SQL
# Assembly
# Bash/Shell
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# SQL
# Bash/Shell
# C
# C#
# C++
# Haskell
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# Ruby
# SQL
# Delphi
# SQL
# Python
# SQL
# HTML/CSS
# JavaScript
# TypeScript
# Delphi
# Go
# HTML/CSS
# JavaScript
# MATLAB
# PHP
# Python
# SQL
# Delphi
# JavaScript
# TypeScript
# Delphi
# Python
# SQL
# C#
# Java
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# Ruby
# C#
# HTML/CSS
# JavaScript
# MATLAB
# PowerShell
# SQL
# TypeScript
# VBA
# HTML/CSS
# JavaScript
# Python
# Ruby
# HTML/CSS
# JavaScript
# Python
# TypeScript
# C
# C++
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# C
# C#
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Objective-C
# PHP
# Swift
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# JavaScript
# HTML/CSS
# JavaScript
# Python
# Bash/Shell
# C
# Ruby
# Rust
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Python
# HTML/CSS
# Java
# SQL
# C
# C++
# Fortran
# Julia
# Python
# Swift
# Java
# PHP
# SQL
# HTML/CSS
# JavaScript
# PHP
# C#
# C++
# Java
# JavaScript
# Python
# SQL
# TypeScript
# Bash/Shell
# R
# HTML/CSS
# JavaScript
# Python
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# VBA
# JavaScript
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Python
# Rust
# TypeScript
# C#
# HTML/CSS
# JavaScript
# Kotlin
# SQL
# JavaScript
# TypeScript
# Kotlin
# HTML/CSS
# JavaScript
# Python
# TypeScript
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# Delphi
# SQL
# C#
# C++
# Delphi
# PHP
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Bash/Shell
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C#
# C++
# SQL
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# PowerShell
# Python
# TypeScript
# C#
# HTML/CSS
# Java
# SQL
# TypeScript
# C#
# Java
# JavaScript
# TypeScript
# C
# C++
# Go
# Python
# C++
# Java
# C#
# Java
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# Java
# C#
# Go
# JavaScript
# Bash/Shell
# Java
# Python
# R
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Python
# Scala
# SQL
# Dart
# HTML/CSS
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# SQL
# HTML/CSS
# JavaScript
# PHP
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# TypeScript
# HTML/CSS
# JavaScript
# Kotlin
# PHP
# Python
# SQL
# TypeScript
# C#
# JavaScript
# C
# C#
# C++
# Dart
# Go
# HTML/CSS
# Java
# JavaScript
# MATLAB
# Objective-C
# Python
# R
# Ruby
# SQL
# Swift
# TypeScript
# VBA
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Bash/Shell
# Java
# Python
# SQL
# C#
# SQL
# Bash/Shell
# C#
# Delphi
# HTML/CSS
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Dart
# JavaScript
# JavaScript
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# C#
# JavaScript
# SQL
# TypeScript
# Dart
# TypeScript
# Kotlin
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# C++
# Elixir
# Go
# HTML/CSS
# Java
# JavaScript
# Lua
# Python
# R
# Ruby
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# ...
# Python
# SQL
# TypeScript
# Bash/Shell
# C
# C++
# Erlang
# Groovy
# Kotlin
# Python
# Rust
# Assembly
# C++
# C#
# Bash/Shell
# Clojure
# Java
# HTML/CSS
# JavaScript
# Rust
# Swift
# TypeScript
# Bash/Shell
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# R
# SQL
# Python
# Assembly
# Bash/Shell
# C
# C++
# C++
# Erlang
# Go
# JavaScript
# Python
# JavaScript
# PHP
# SQL
# C
# C++
# MATLAB
# Python
# SQL
# C#
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Dart
# Kotlin
# Python
# HTML/CSS
# JavaScript
# Python
# Rust
# SQL
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# C
# C#
# JavaScript
# PowerShell
# Python
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PowerShell
# TypeScript
# Java
# JavaScript
# Python
# SQL
# TypeScript
# Kotlin
# Bash/Shell
# C
# C++
# HTML/CSS
# Python
# VBA
# C#
# Java
# JavaScript
# Python
# TypeScript
# Bash/Shell
# Python
# SQL
# HTML/CSS
# R
# Bash/Shell
# C
# C#
# C++
# MATLAB
# Python
# PHP
# SQL
# C#
# HTML/CSS
# Java
# JavaScript
# PowerShell
# SQL
# TypeScript
# VBA
# C#
# HTML/CSS
# JavaScript
# PHP
# Python
# Java
# Python
# SQL
# C#
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# C
# C#
# C++
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# Go
# Python
# Assembly
# Bash/Shell
# C
# HTML/CSS
# Java
# JavaScript
# Lua
# MATLAB
# Objective-C
# PHP
# TypeScript
# Bash/Shell
# Go
# Python
# C#
# HTML/CSS
# TypeScript
# HTML/CSS
# Java
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# C#
# HTML/CSS
# PowerShell
# JavaScript
# Ruby
# Swift
# Kotlin
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Bash/Shell
# C
# MATLAB
# PowerShell
# Python
# Rust
# VBA
# Bash/Shell
# C#
# C++
# F#
# HTML/CSS
# Java
# JavaScript
# PowerShell
# Rust
# SQL
# Bash/Shell
# C#
# Delphi
# HTML/CSS
# JavaScript
# Lua
# PowerShell
# TypeScript
# Assembly
# C
# C#
# C++
# Julia
# Python
# Rust
# Bash/Shell
# Java
# HTML/CSS
# JavaScript
# Rust
# HTML/CSS
# Python
# SQL
# C#
# F#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# Bash/Shell
# C#
# Go
# Java
# PowerShell
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Go
# C
# C++
# HTML/CSS
# Python
# SQL
# TypeScript
# C#
# Java
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# Bash/Shell
# C
# C++
# Go
# Java
# JavaScript
# Python
# Java
# JavaScript
# SQL
# HTML/CSS
# TypeScript
# Bash/Shell
# C++
# Java
# JavaScript
# Python
# C#
# C++
# HTML/CSS
# Java
# PHP
# Python
# SQL
# C#
# C#
# C++
# SQL
# Elixir
# Kotlin
# JavaScript
# Kotlin
# Python
# C
# Go
# Python
# Ruby
# SQL
# Bash/Shell
# Groovy
# Java
# JavaScript
# Python
# SQL
# C#
# C++
# Dart
# JavaScript
# MATLAB
# PowerShell
# Python
# TypeScript
# Bash/Shell
# Go
# HTML/CSS
# Java
# JavaScript
# Python
# Ruby
# SQL
# TypeScript
# Python
# Scala
# SQL
# HTML/CSS
# JavaScript
# PHP
# C
# C++
# Python
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# Java
# JavaScript
# Kotlin
# TypeScript
# Bash/Shell
# C
# Go
# Java
# JavaScript
# Perl
# Python
# Ruby
# SQL
# TypeScript
# C++
# Python
# R
# Go
# Java
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# C++
# COBOL
# Groovy
# HTML/CSS
# Java
# JavaScript
# MATLAB
# PHP
# PowerShell
# Python
# SQL
# VBA
# Go
# Haskell
# JavaScript
# R
# Solidity
# TypeScript
# C#
# F#
# HTML/CSS
# JavaScript
# Python
# Solidity
# Python
# HTML/CSS
# JavaScript
# Bash/Shell
# C#
# Dart
# HTML/CSS
# Java
# JavaScript
# Lua
# PowerShell
# Python
# SQL
# TypeScript
# Delphi
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# C
# C++
# Groovy
# HTML/CSS
# Java
# JavaScript
# Python
# Rust
# SQL
# Go
# Java
# JavaScript
# C#
# Objective-C
# Ruby
# Java
# Kotlin
# Python
# TypeScript
# Go
# JavaScript
# TypeScript
# PHP
# SQL
# Swift
# JavaScript
# PHP
# SQL
# TypeScript
# Python
# SQL
# Java
# JavaScript
# PHP
# Bash/Shell
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Rust
# TypeScript
# C#
# PowerShell
# Python
# Solidity
# SQL
# Java
# JavaScript
# PHP
# TypeScript
# Bash/Shell
# C++
# Python
# SQL
# Haskell
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# PHP
# SQL
# Dart
# SQL
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# C++
# C
# C#
# C++
# Delphi
# Java
# PowerShell
# Go
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# VBA
# Ruby
# TypeScript
# Bash/Shell
# HTML/CSS
# Java
# Scala
# SQL
# APL
# C
# Haskell
# Julia
# MATLAB
# Python
# R
# SQL
# JavaScript
# Python
# HTML/CSS
# JavaScript
# Ruby
# Bash/Shell
# Java
# JavaScript
# Kotlin
# Python
# Scala
# SQL
# TypeScript
# Bash/Shell
# C#
# Groovy
# HTML/CSS
# Java
# JavaScript
# PowerShell
# SQL
# TypeScript
# C#
# PowerShell
# SQL
# C#
# Dart
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Go
# HTML/CSS
# JavaScript
# Rust
# SQL
# TypeScript
# Kotlin
# Python
# Swift
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Objective-C
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Kotlin
# SQL
# C
# C#
# C++
# Delphi
# HTML/CSS
# Java
# SQL
# Elixir
# HTML/CSS
# JavaScript
# Ruby
# C++
# PowerShell
# Python
# R
# SAS
# SQL
# Bash/Shell
# C#
# Dart
# Groovy
# JavaScript
# PowerShell
# Python
# SQL
# TypeScript
# C++
# Python
# Python
# Rust
# Bash/Shell
# Go
# SQL
# TypeScript
# Bash/Shell
# Groovy
# Java
# Kotlin
# Python
# SQL
# Bash/Shell
# C#
# JavaScript
# Python
# Rust
# SQL
# Go
# Java
# JavaScript
# SQL
# TypeScript
# Java
# TypeScript
# Elixir
# HTML/CSS
# Dart
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# Bash/Shell
# Java
# SQL
# Bash/Shell
# C
# HTML/CSS
# Java
# JavaScript
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# SQL
# VBA
# Python
# Bash/Shell
# Dart
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# C
# C#
# C++
# JavaScript
# PHP
# SQL
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Bash/Shell
# Java
# JavaScript
# Bash/Shell
# HTML/CSS
# JavaScript
# Perl
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Python
# R
# SQL
# Kotlin
# Python
# Ruby
# SQL
# Swift
# Bash/Shell
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# TypeScript
# HTML/CSS
# TypeScript
# HTML/CSS
# JavaScript
# PowerShell
# Ruby
# SQL
# TypeScript
# Assembly
# C
# C#
# C++
# Delphi
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# C++
# JavaScript
# Python
# VBA
# Clojure
# Java
# Scala
# Bash/Shell
# JavaScript
# PHP
# SQL
# TypeScript
# Java
# Java
# HTML/CSS
# JavaScript
# Ruby
# TypeScript
# HTML/CSS
# JavaScript
# Python
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# TypeScript
# C
# Java
# Bash/Shell
# C++
# Java
# JavaScript
# TypeScript
# Java
# PHP
# SQL
# HTML/CSS
# JavaScript
# Kotlin
# PHP
# SQL
# Swift
# TypeScript
# C
# C#
# C++
# Dart
# Go
# Java
# JavaScript
# PHP
# SQL
# TypeScript
# Bash/Shell
# Java
# Lua
# Python
# Scala
# Bash/Shell
# Clojure
# Go
# Groovy
# Python
# C#
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# VBA
# Delphi
# Kotlin
# Assembly
# C#
# C++
# Delphi
# HTML/CSS
# JavaScript
# Lua
# PHP
# SQL
# TypeScript
# C++
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# PowerShell
# Python
# C#
# JavaScript
# PowerShell
# TypeScript
# Bash/Shell
# Fortran
# JavaScript
# Python
# Rust
# TypeScript
# Ruby
# Clojure
# HTML/CSS
# Java
# JavaScript
# TypeScript
# C
# C#
# C++
# HTML/CSS
# JavaScript
# MATLAB
# PowerShell
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# C#
# F#
# PowerShell
# SQL
# VBA
# Go
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# C#
# Go
# HTML/CSS
# JavaScript
# PHP
# C
# Go
# Java
# JavaScript
# Python
# Scala
# SQL
# TypeScript
# TypeScript
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Rust
# TypeScript
# Java
# Kotlin
# Objective-C
# Rust
# Swift
# TypeScript
# C#
# Swift
# TypeScript
# C#
# Haskell
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PowerShell
# Rust
# SQL
# APL
# C#
# SQL
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# Java
# Python
# Dart
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C#
# Java
# PowerShell
# Python
# Java
# Python
# C
# C#
# C++
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# SQL
# C#
# HTML/CSS
# JavaScript
# PowerShell
# R
# SQL
# TypeScript
# VBA
# Bash/Shell
# C
# C++
# HTML/CSS
# Java
# JavaScript
# MATLAB
# PHP
# PowerShell
# SQL
# Assembly
# C
# C#
# C++
# Java
# Python
# R
# Scala
# SQL
# Bash/Shell
# C#
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Python
# SQL
# TypeScript
# Bash/Shell
# Scala
# SQL
# Go
# HTML/CSS
# JavaScript
# Ruby
# SQL
# Groovy
# Kotlin
# TypeScript
# Bash/Shell
# C#
# Go
# Groovy
# Java
# JavaScript
# Python
# Ruby
# Scala
# SQL
# TypeScript
# Java
# Kotlin
# Python
# SQL
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# SQL
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C#
# COBOL
# HTML/CSS
# JavaScript
# PowerShell
# SAS
# SQL
# TypeScript
# Java
# SQL
# Dart
# JavaScript
# Python
# Rust
# SQL
# TypeScript
# Bash/Shell
# C
# Java
# Rust
# TypeScript
# HTML/CSS
# Java
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# Python
# Ruby
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# R
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# Bash/Shell
# Elixir
# Erlang
# HTML/CSS
# JavaScript
# Python
# C
# C#
# C++
# Crystal
# HTML/CSS
# Java
# JavaScript
# PHP
# SQL
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# SQL
# Assembly
# Bash/Shell
# C
# C#
# JavaScript
# PowerShell
# Python
# VBA
# Bash/Shell
# C#
# Go
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# Java
# JavaScript
# PowerShell
# SQL
# TypeScript
# Python
# R
# C++
# Python
# Rust
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# C#
# Dart
# Groovy
# HTML/CSS
# Java
# JavaScript
# Solidity
# TypeScript
# Bash/Shell
# Go
# Java
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# HTML/CSS
# JavaScript
# PHP
# C#
# C#
# C++
# Dart
# Elixir
# Erlang
# F#
# Go
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Ruby
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# VBA
# HTML/CSS
# JavaScript
# C
# HTML/CSS
# JavaScript
# Objective-C
# PHP
# SQL
# Clojure
# Assembly
# Bash/Shell
# C
# C#
# C++
# Java
# JavaScript
# PowerShell
# Rust
# SQL
# TypeScript
# VBA
# HTML/CSS
# Java
# Kotlin
# Python
# SQL
# Python
# Bash/Shell
# JavaScript
# Python
# C#
# HTML/CSS
# JavaScript
# SQL
# Bash/Shell
# JavaScript
# Ruby
# C#
# Python
# SQL
# Julia
# SQL
# C#
# SQL
# HTML/CSS
# JavaScript
# Rust
# TypeScript
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# PowerShell
# Python
# SQL
# TypeScript
# Assembly
# Bash/Shell
# C
# C++
# HTML/CSS
# MATLAB
# PowerShell
# Python
# Rust
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Go
# Java
# JavaScript
# Bash/Shell
# C#
# Elixir
# Go
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# C#
# C
# C#
# C++
# Dart
# Go
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# SQL
# Swift
# TypeScript
# HTML/CSS
# JavaScript
# SAS
# C#
# Go
# Swift
# Bash/Shell
# C
# Elixir
# Erlang
# Go
# HTML/CSS
# JavaScript
# Python
# Rust
# SQL
# JavaScript
# TypeScript
# Java
# Python
# SQL
# TypeScript
# JavaScript
# PHP
# Java
# JavaScript
# Python
# Swift
# JavaScript
# Python
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# Java
# Kotlin
# SQL
# Assembly
# Bash/Shell
# HTML/CSS
# JavaScript
# MATLAB
# Python
# R
# SQL
# Go
# Python
# HTML/CSS
# Julia
# PowerShell
# Python
# R
# Scala
# VBA
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# R
# SAS
# SQL
# HTML/CSS
# JavaScript
# Bash/Shell
# PHP
# SQL
# Assembly
# Bash/Shell
# C
# C#
# C++
# COBOL
# Fortran
# HTML/CSS
# JavaScript
# PowerShell
# Python
# Ruby
# SQL
# Swift
# HTML/CSS
# TypeScript
# Assembly
# Bash/Shell
# C
# C++
# HTML/CSS
# JavaScript
# Python
# Ruby
# Rust
# TypeScript
# Elixir
# HTML/CSS
# JavaScript
# Kotlin
# C
# C#
# C++
# Rust
# Bash/Shell
# C++
# Python
# Rust
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# SQL
# C
# Elixir
# Go
# Java
# Rust
# TypeScript
# Assembly
# Bash/Shell
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# Solidity
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# VBA
# Go
# JavaScript
# Rust
# TypeScript
# Bash/Shell
# C#
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Java
# SQL
# Swift
# TypeScript
# C#
# C++
# Dart
# Bash/Shell
# Groovy
# HTML/CSS
# Java
# JavaScript
# Perl
# PowerShell
# Python
# R
# Ruby
# SQL
# JavaScript
# Python
# Rust
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# Delphi
# Bash/Shell
# C#
# HTML/CSS
# Rust
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PHP
# SQL
# Bash/Shell
# C
# C++
# Java
# Python
# Rust
# C#
# Go
# HTML/CSS
# JavaScript
# Kotlin
# PowerShell
# Python
# SQL
# TypeScript
# C#
# Clojure
# Julia
# Bash/Shell
# Go
# HTML/CSS
# JavaScript
# PHP
# Python
# SQL
# TypeScript
# HTML/CSS
# Python
# SQL
# JavaScript
# TypeScript
# C#
# JavaScript
# TypeScript
# C
# C#
# C++
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# Rust
# SQL
# TypeScript
# Bash/Shell
# Go
# HTML/CSS
# JavaScript
# Python
# SQL
# TypeScript
# C#
# SQL
# VBA
# Clojure
# Go
# JavaScript
# Python
# TypeScript
# Bash/Shell
# C#
# C++
# Go
# HTML/CSS
# JavaScript
# Kotlin
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# Java
# JavaScript
# SQL
# JavaScript
# Bash/Shell
# C
# C++
# HTML/CSS
# Lua
# Python
# Rust
# C#
# HTML/CSS
# JavaScript
# Python
# R
# SQL
# Bash/Shell
# Go
# HTML/CSS
# Java
# JavaScript
# JavaScript
# Kotlin
# JavaScript
# Swift
# HTML/CSS
# Java
# JavaScript
# Kotlin
# TypeScript
# Go
# Kotlin
# Ruby
# Rust
# TypeScript
# C++
# PowerShell
# Python
# SQL
# TypeScript
# C
# C#
# Delphi
# HTML/CSS
# Java
# JavaScript
# Objective-C
# PHP
# Python
# Ruby
# TypeScript
# C#
# Clojure
# Java
# JavaScript
# SQL
# TypeScript
# Java
# SQL
# Java
# HTML/CSS
# Ruby
# SQL
# TypeScript
# Bash/Shell
# Go
# HTML/CSS
# JavaScript
# Ruby
# SQL
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PowerShell
# Python
# SQL
# TypeScript
# Bash/Shell
# SQL
# TypeScript
# Assembly
# C
# C#
# C++
# Python
# Bash/Shell
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# HTML/CSS
# Java
# SQL
# TypeScript
# Bash/Shell
# HTML/CSS
# Java
# Perl
# PHP
# PowerShell
# Python
# R
# SAS
# SQL
# VBA
# Bash/Shell
# C
# C#
# Delphi
# Go
# Groovy
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C
# Groovy
# HTML/CSS
# JavaScript
# Python
# SQL
# C#
# C++
# Fortran
# HTML/CSS
# JavaScript
# Bash/Shell
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# PowerShell
# Python
# R
# Ruby
# Solidity
# SQL
# TypeScript
# Bash/Shell
# Go
# Python
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# HTML/CSS
# PowerShell
# Python
# SQL
# Bash/Shell
# HTML/CSS
# Java
# JavaScript
# SQL
# C#
# HTML/CSS
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# Dart
# Groovy
# Java
# JavaScript
# Kotlin
# Objective-C
# PowerShell
# Python
# Ruby
# Rust
# SQL
# TypeScript
# Bash/Shell
# Python
# C#
# SQL
# C++
# Haskell
# Python
# Bash/Shell
# Python
# Rust
# TypeScript
# Bash/Shell
# Go
# Java
# JavaScript
# Python
# TypeScript
# Delphi
# PowerShell
# SQL
# VBA
# Bash/Shell
# C#
# C++
# Erlang
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PHP
# PowerShell
# Python
# Ruby
# Scala
# SQL
# Swift
# Python
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# Ruby
# SQL
# C++
# HTML/CSS
# JavaScript
# Solidity
# SQL
# TypeScript
# JavaScript
# Bash/Shell
# Go
# HTML/CSS
# JavaScript
# Python
# R
# Rust
# SQL
# VBA
# Bash/Shell
# C
# C#
# C++
# F#
# Fortran
# PowerShell
# Python
# SQL
# VBA
# Bash/Shell
# Groovy
# Java
# JavaScript
# Kotlin
# SQL
# Go
# Kotlin
# Python
# TypeScript
# C#
# Elixir
# Erlang
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# Lua
# Rust
# Solidity
# TypeScript
# C#
# C++
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# Bash/Shell
# C++
# HTML/CSS
# JavaScript
# Python
# Go
# Kotlin
# Rust
# Bash/Shell
# C#
# Go
# SQL
# Bash/Shell
# Java
# JavaScript
# PHP
# PowerShell
# Python
# Swift
# Bash/Shell
# C
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# C
# C#
# C++
# Dart
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# C#
# Java
# HTML/CSS
# JavaScript
# HTML/CSS
# JavaScript
# PHP
# TypeScript
# Dart
# Swift
# Assembly
# Bash/Shell
# C
# C++
# Go
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# Dart
# JavaScript
# Kotlin
# Python
# SQL
# C#
# HTML/CSS
# JavaScript
# Rust
# TypeScript
# C
# C++
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# HTML/CSS
# PHP
# Python
# Rust
# SQL
# C
# C#
# Delphi
# SQL
# Bash/Shell
# Haskell
# Python
# C++
# HTML/CSS
# JavaScript
# Python
# SQL
# HTML/CSS
# JavaScript
# Python
# SQL
# Bash/Shell
# C#
# C++
# Go
# HTML/CSS
# JavaScript
# PowerShell
# Python
# SQL
# TypeScript
# Bash/Shell
# Go
# HTML/CSS
# Java
# JavaScript
# Python
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# TypeScript
# C#
# Go
# HTML/CSS
# JavaScript
# Python
# Clojure
# Java
# TypeScript
# Python
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# Python
# TypeScript
# Bash/Shell
# C
# C#
# HTML/CSS
# JavaScript
# Perl
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Scala
# SQL
# TypeScript
# Groovy
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PowerShell
# Python
# SQL
# TypeScript
# C#
# Rust
# SQL
# PowerShell
# Python
# SQL
# HTML/CSS
# PowerShell
# SQL
# Bash/Shell
# C++
# Python
# R
# F#
# Python
# R
# VBA
# C++
# HTML/CSS
# Java
# JavaScript
# PHP
# Python
# SQL
# Swift
# TypeScript
# Assembly
# Bash/Shell
# C
# HTML/CSS
# Java
# JavaScript
# Kotlin
# Perl
# Python
# Rust
# Solidity
# Bash/Shell
# C
# C++
# Groovy
# Java
# JavaScript
# Python
# Rust
# SQL
# HTML/CSS
# Java
# JavaScript
# TypeScript
# HTML/CSS
# JavaScript
# TypeScript
# Bash/Shell
# HTML/CSS
# PowerShell
# Python
# C#
# Delphi
# PowerShell
# Python
# SQL
# C
# C++
# Go
# Java
# JavaScript
# Kotlin
# Lua
# Python
# Scala
# SQL
# TypeScript
# Elixir
# Erlang
# Go
# HTML/CSS
# Ruby
# Rust
# SQL
# JavaScript
# PHP
# Python
# SAS
# SQL
# TypeScript
# Dart
# Elixir
# TypeScript
# C++
# Delphi
# HTML/CSS
# JavaScript
# SAS
# SQL
# VBA
# Bash/Shell
# JavaScript
# Python
# Ruby
# TypeScript
# C
# Java
# C#
# HTML/CSS
# Java
# Kotlin
# TypeScript
# Bash/Shell
# C
# C#
# C++
# HTML/CSS
# Java
# JavaScript
# SQL
# TypeScript
# JavaScript
# Python
# PowerShell
# Python
# Groovy
# Java
# Kotlin
# Python
# Java
# Kotlin
# TypeScript
# C#
# HTML/CSS
# JavaScript
# SQL
# Bash/Shell
# HTML/CSS
# JavaScript
# PHP
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# C++
# JavaScript
# Lua
# PowerShell
# Python
# Ruby
# Rust
# SQL
# Bash/Shell
# C#
# Dart
# Go
# Groovy
# HTML/CSS
# Java
# JavaScript
# Kotlin
# PowerShell
# Python
# SQL
# TypeScript
# C#
# HTML/CSS
# JavaScript
# PowerShell
# TypeScript
# Bash/Shell
# HTML/CSS
# JavaScript
# Python
# SQL
# Java
# JavaScript
# SQL
# TypeScript
# Bash/Shell
# C
# C#
# C++
# Java
# Python
# SQL
# Bash/Shell
# C#
# HTML/CSS
# Java
# JavaScript
# Python
# TypeScript
# Bash/Shell
# C
# C++
# Fortran
# Groovy
# Lua
# MATLAB
# Python
# R
# Ruby
# SQL
# VBA
# Bash/Shell
# C
# C++
# HTML/CSS
# JavaScript
# PHP
# PowerShell
# Python
# SQL
# TypeScript
# Bash/Shell
# Julia
# PowerShell
# Python
# R
# SQL
# HTML/CSS
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# Perl
# SQL
# Bash/Shell
# C#
# HTML/CSS
# JavaScript
# PowerShell
# SQL
# TypeScript
# Python
# C#
# Go
# HTML/CSS
# TypeScript
# C
# HTML/CSS
# Java
# JavaScript
# PHP
# PowerShell
# SQL
# C
# C#
# C++
# Python
# Go
# HTML/CSS
# JavaScript
# SQL
# C++
# JavaScript
# TypeScript
# C
# C++
# Go
# JavaScript
# TypeScript
# Java
# Kotlin
# SQL

# %%
type(all_languages)
# Out:
# list

# %%
meanSalary = pd.DataFrame(data = np.zeros(len(all_languages)), index = all_languages, columns = ["Salary"])
meanSalary
# Out:
#              Salary
# Python          0.0
# Delphi          0.0
# Bash/Shell      0.0
# C               0.0
# C#              0.0
# HTML/CSS        0.0
# JavaScript      0.0
# PHP             0.0
# SQL             0.0
# TypeScript      0.0
# Java            0.0
# Lua             0.0
# C++             0.0
# Fortran         0.0
# MATLAB          0.0
# R               0.0
# Ruby            0.0
# Perl            0.0
# PowerShell      0.0
# Elixir          0.0
# Erlang          0.0
# Groovy          0.0
# Objective-C     0.0
# Dart            0.0
# Kotlin          0.0
# Solidity        0.0
# Assembly        0.0
# VBA             0.0
# Go              0.0
# Rust            0.0
# F#              0.0
# Haskell         0.0
# Scala           0.0
# Swift           0.0
# APL             0.0
# LISP            0.0
# Crystal         0.0
# Julia           0.0
# OCaml           0.0
# COBOL           0.0
# SAS             0.0
# Clojure         0.0

# %%
#comentario: pense en hacerlo con fuerza bruta, pero mi pc no lo pudo correr
#Calculo de Salario medio para cada lenguaje
#lista1=[]
#for i in all_languages:
#    lista=[]
#    for l,m in enumerate(lengua):
#        for k in m.split(";"):
#            if i == k:
#                lista.append(df_survey["Salary"][:l+1]) 

#    lista1.append(sum(lista)/len(lista))

# %%
#Calculo de salario de una manera mas inteligente
import re

for lang in all_languages:
    try:
        mask = df_survey["Languages"].str.contains(re.escape(lang))
        average = df_survey.loc[mask, "Salary"].mean()
        meanSalary.loc[lang, "Salary"] = round(average,1)
    except Exception:
        print(lang)

meanSalary
# Out:
#                Salary
# Python       106298.1
# Delphi        92073.3
# Bash/Shell   113133.1
# C            101244.6
# C#           100269.0
# HTML/CSS      97879.2
# JavaScript    99724.9
# PHP           85249.4
# SQL          101463.3
# TypeScript   103383.6
# Java         100327.1
# Lua          110044.1
# C++          108855.2
# Fortran      112717.2
# MATLAB        92789.5
# R            117585.1
# Ruby         121224.9
# Perl         117595.0
# PowerShell   108671.1
# Elixir       121345.9
# Erlang       137986.9
# Groovy       117019.2
# Objective-C  114017.9
# Dart          88407.5
# Kotlin       106629.9
# Solidity     120285.0
# Assembly     115893.9
# VBA           96432.8
# Go           123996.8
# Rust         122623.1
# F#           124762.2
# Haskell      114285.5
# Scala        126443.6
# Swift        110535.0
# APL          118910.4
# LISP         114894.7
# Crystal      115044.3
# Julia        113315.5
# OCaml        122110.6
# COBOL        112330.7
# SAS          121534.4
# Clojure      134247.8

# %%
#Grafica de los lenguajes vs sus ingresos anuales
colors = [
    "#03071E",
    "#370617",
    "#6A040F",
    "#9D0208",
    "#D00000",
    "#DC2F02",
    "#E85D04",
    "#F48C06",
    "#FAA307",
    "#FFBA08"
]

#Permite sacar el grafico por una ventana emergente
#pip install PyQt5
# %matplotlib qt5

#plt.style.use("seaborn")

meanSalary.sort_values(by="Salary", inplace=True)
plt.barh(meanSalary.index, meanSalary["Salary"], color=colors)
plt.vlines(meanSalary["Salary"].mean(), 0, len(meanSalary["Salary"]), colors="red", linestyles="dashed", label="Mean Salary")

plt.title("Programming Languages Yearly Compensation")
plt.xlabel("Mean Salary in $")
plt.ylabel("Programming languages")

plt.gca().xaxis.set_major_formatter('${x:1.0f}')
plt.tight_layout()
plt.show()

# %%
#Grafica un poco mas arreglada

#promedio de los valores del salario
meanSalary["Salary"].mean()
#indice del valor mas cercano al promedio
meanSalary.index.get_loc("COBOL")
#Quiero imprimir 30 valores, 15 por encima del promedio y 15 por debajo
meanSalary30 = meanSalary[:][3:33]

#pip install PyQt5
# %matplotlib qt5

meanSalary.sort_values(by="Salary", inplace=True)
plt.barh(meanSalary30.index, meanSalary30["Salary"])
plt.vlines(meanSalary30["Salary"].mean(), 0, len(meanSalary30["Salary"]), colors="red", linestyles="dashed", label="Mean Salary")

plt.title("Programming Languages Yearly Compensation")
plt.xlabel("Mean Salary in $")
plt.ylabel("Programming languages")

plt.gca().xaxis.set_major_formatter('${x:1.0f}')
plt.tight_layout()
plt.show()
